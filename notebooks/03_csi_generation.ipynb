# %% [markdown]
# # 03 CSI Generation
#
# Goal: generate synthetic CSI-like amplitude and phase vectors from path-level channel models.

# %%
import numpy as np
import matplotlib.pyplot as plt

subcarriers = np.arange(-28, 29)
subcarriers = subcarriers[subcarriers != 0]
subcarriers.shape
