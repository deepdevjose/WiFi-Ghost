# %% [markdown]
# # 04 Motion Detection
#
# Goal: test baseline subtraction, rolling variance, and motion scoring on synthetic and recorded CSI sequences.

# %%
import numpy as np
import matplotlib.pyplot as plt

def motion_score(samples, baseline):
    return np.linalg.norm(samples - baseline, axis=-1)
