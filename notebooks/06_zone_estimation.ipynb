# %% [markdown]
# # 06 Zone Estimation
#
# Goal: evaluate coarse room-zone classification after simulation and calibration make it plausible.

# %%
zones = [
    "near_transmitter",
    "near_receiver",
    "central_path",
    "wall_or_doorway",
    "outside_monitored_region",
]
zones
