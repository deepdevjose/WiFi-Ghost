# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 01 Signal Propagation
#
# Goal: model a room with one transmitter, one receiver, one person, a direct path, one reflected path, and noise.
#
# Start here before CSI. The first useful model is:
#
# `received = direct_path + reflected_path + noise`

# %%
C = 299_792_458
FREQ_HZ = 2.4e9
WAVELENGTH_M = C / FREQ_HZ
WAVELENGTH_M
# Out:
# 0.12491352416666666
