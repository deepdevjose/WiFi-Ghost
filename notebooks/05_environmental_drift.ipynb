# %% [markdown]
# # 05 Environmental Drift
#
# Goal: model slow nuisance variation from temperature, humidity, device drift, and baseline shift.

# %%
import numpy as np
import matplotlib.pyplot as plt

minutes = np.linspace(0, 60, 600)
slow_drift = 0.02 * np.sin(2 * np.pi * minutes / 60)
slow_drift[:5]
