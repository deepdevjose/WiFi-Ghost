# %% [markdown]
# # 07 Virtual Room
#
# Goal: render the simulated room, walls, transmitter, receiver, person, and estimated zone before implementing the production dashboard.

# %%
# Suggested first pass: use plotly for a lightweight interactive room sketch.
# Upgrade to pythreejs only if notebook-native 3D interaction becomes useful.
room = {"width_m": 5.0, "depth_m": 4.0, "height_m": 2.5}
tx = {"x": 0.5, "y": 2.0, "z": 1.2}
rx = {"x": 4.5, "y": 2.0, "z": 1.2}
room, tx, rx
